# %% [markdown]
# <a href="https://colab.research.google.com/github/gauravblog-art/Stock_Preiction_Using_Python/blob/main/internship.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # compare the Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import datetime

# %%
#in this we are going to print all data of bosch
df1 = pd.read_csv('/content/drive/MyDrive/data analatics/Bosch.csv')
print(df1)

rcParams['figure.figsize']=10,6
plt.xlabel('Date')
plt.ylabel("stock price")
plt.title('Bosch')
plt.ylim()
plt.plot(df1.Date,df1 .Open, label ='Open')
plt.plot(df1.Date,df1.High, label ='High')
plt.plot(df1.Date,df1.Low, label ='Low')
plt.plot(df1.Date,df1.Close, label ='Close')
plt.legend()
plt.show()
# Out:
#           Date    Open  ...  Spread H-L  Spread C-O
# 0   2021-06-18  175.05  ...       12.40       -1.45
# 1   2021-06-17  163.15  ...       15.00       11.35
# 2   2021-06-16  156.20  ...        8.90        5.15
# 3   2021-06-15  154.15  ...        2.90       -1.95
# 4   2021-06-14  155.90  ...        3.65       -3.20
# ..         ...     ...  ...         ...         ...
# 57  2021-03-24  115.55  ...        5.10       -0.30
# 58  2021-03-23  115.65  ...        4.05       -0.80
# 59  2021-03-22  114.70  ...        4.50        0.60
# 60  2021-03-19  110.90  ...       13.25        4.20
# 61  2021-03-18  117.90  ...        8.70       -6.55
#
# [62 rows x 13 columns]

# %%
df2 = pd.read_csv('/content/drive/MyDrive/data analatics/EOD-AAPL APPLE(3M).csv')
print(df2)
df2.head()
rcParams['figure.figsize']=10,6
plt.xlabel('Date')
plt.ylabel("stock price")
plt.title('EOD-AAPL APPLE')
plt.plot(df2.Date,df2.Open, label ='Open')
plt.plot(df2.Date,df2.High, label ='High')
plt.plot(df2.Date,df2.Low, label ='Low')
plt.plot(df2.Date,df2.Close, label ='Close')
plt.legend()
plt.show()
df2.head()
# Out:
#           Date     Open  ...  Spread H-L  Spread C-O
# 0   2021-06-18  3169.00  ...      180.45       12.50
# 1   2021-06-17  3139.75  ...       65.05       10.20
# 2   2021-06-16  3175.50  ...       89.75      -22.85
# 3   2021-06-15  3210.00  ...       92.25      -12.55
# 4   2021-06-14  3214.35  ...      136.35        1.75
# ..         ...      ...  ...         ...         ...
# 57  2021-03-24  2599.00  ...      134.15     -123.65
# 58  2021-03-23  2593.80  ...       76.50      -37.65
# 59  2021-03-22  2533.00  ...       51.70       39.40
# 60  2021-03-19  2410.00  ...      148.25      108.15
# 61  2021-03-18  2467.00  ...      137.55      -52.20
#
# [62 rows x 13 columns]
#          Date     Open  ...  Spread H-L  Spread C-O
# 0  2021-06-18  3169.00  ...      180.45       12.50
# 1  2021-06-17  3139.75  ...       65.05       10.20
# 2  2021-06-16  3175.50  ...       89.75      -22.85
# 3  2021-06-15  3210.00  ...       92.25      -12.55
# ...

# %%
df3=pd.read_csv('/content/drive/MyDrive/data analatics/EOD-INTC Intel(3M).csv')
print(df3)
rcParams['figure.figsize']=10,6

plt.xlabel('Date')
plt.ylabel("stock price")
plt.title('Intel')
plt.ylim()
plt.plot(df3.Date,df3.Open, label='Open')
plt.plot(df3.Date,df3.High, label='High')
plt.plot(df3.Date,df3.Low, label='Low')
plt.plot(df3.Date,df3.Close, label='Close')
plt.legend()
plt.show()
df3.head()
# Out:
#           Date    Open  ...  Spread H-L  Spread C-O
# 0   2021-06-18  213.00  ...        9.20       -2.45
# 1   2021-06-17  212.00  ...        4.40        0.95
# 2   2021-06-16  218.00  ...        5.40       -3.25
# 3   2021-06-15  219.30  ...        7.30       -2.10
# 4   2021-06-14  225.00  ...       11.25       -6.45
# ..         ...     ...  ...         ...         ...
# 57  2021-03-24  222.70  ...       10.25       -5.30
# 58  2021-03-23  222.85  ...        6.05       -0.15
# 59  2021-03-22  225.00  ...        4.70       -2.15
# 60  2021-03-19  223.00  ...        9.00       -0.45
# 61  2021-03-18  232.25  ...        9.35       -6.25
#
# [62 rows x 13 columns]
#          Date   Open    High  ...  % Deli. Qty to Traded Qty  Spread H-L  Spread C-O
# 0  2021-06-18  213.0  215.05  ...                      56.28        9.20       -2.45
# 1  2021-06-17  212.0  216.40  ...                      46.12        4.40        0.95
# ...

# %%
from pandas_profiling import  ProfileReport
df4=pd.read_csv('/content/drive/MyDrive/data analatics/EOD-IBM (3M).csv')
print(df4)
rcParams['figure.figsize']=10,6
plt.xlabel('Date')
plt.ylabel("stock price")
plt.title('AffleIndia')
plt.ylim()
plt.plot(df4.Date,df4.Open, label ='Open')
plt.plot(df4.Date,df4.High, label ='High')
plt.plot(df4.Date,df4.Low, label ='Low')
plt.plot(df4.Date,df4.Close, label ='Close')
plt.show()
df4.head()
# Out:
#           Date  Open   High  ...  % Deli. Qty to Traded Qty  Spread H-L  Spread C-O
# 0   2021-06-18  9.95  10.20  ...                      68.73        0.83       -0.51
# 1   2021-06-17  9.97  10.05  ...                      54.96        0.35       -0.11
# 2   2021-06-16  9.50   9.58  ...                      77.38        0.53        0.08
# 3   2021-06-15  9.44   9.44  ...                      64.60        0.43       -0.31
# 4   2021-06-14  9.06   9.31  ...                      67.42        0.36        0.11
# ..         ...   ...    ...  ...                        ...         ...         ...
# 57  2021-03-24  5.85   6.03  ...                     100.00        0.37       -0.12
# 58  2021-03-23  6.00   6.00  ...                     100.00        0.35       -0.11
# 59  2021-03-22  5.88   6.11  ...                     100.00        0.23        0.00
# 60  2021-03-19  6.01   6.29  ...                     100.00        0.49        0.17
# ...

# %%
df5=pd.read_csv('/content/drive/MyDrive/data analatics/EOD-MSFT Microsoft Corporation(3M) (1).csv')
print(df5)
rcParams['figure.figsize']=10,6
plt.xlabel('Date')
plt.ylabel("stock price")
plt.title('Microsoft Corporation ')
plt.ylim()
plt.plot(df5.Date,df5.Open, label ='Open')
plt.plot(df5.Date,df5.High, label ='High')
plt.plot(df5.Date,df5.Low, label ='Low')
plt.plot(df5.Date,df5.Close, label ='Close')
plt.legend()
plt.show()
df5.head()
# Out:
#           Date    Open  ...  Spread H-L  Spread C-O
# 0   2021-06-18  250.90  ...       18.10       -8.25
# 1   2021-06-17  251.95  ...        8.85       -3.15
# 2   2021-06-16  262.00  ...       13.75      -10.00
# 3   2021-06-15  251.85  ...       14.70        2.95
# 4   2021-06-14  248.30  ...       20.45       -0.30
# ..         ...     ...  ...         ...         ...
# 57  2021-03-24  188.00  ...        5.75       -3.40
# 58  2021-03-23  185.60  ...        4.65        1.35
# 59  2021-03-22  186.55  ...       10.85        1.15
# 60  2021-03-19  181.25  ...        8.90        6.05
# 61  2021-03-18  192.00  ...       16.85       -8.30
#
# [62 rows x 13 columns]
#          Date    Open  ...  Spread H-L  Spread C-O
# 0  2021-06-18  250.90  ...       18.10       -8.25
# 1  2021-06-17  251.95  ...        8.85       -3.15
# 2  2021-06-16  262.00  ...       13.75      -10.00
# 3  2021-06-15  251.85  ...       14.70        2.95
# 4  2021-06-14  248.30  ...       20.45       -0.30
#
# ...

# %% [markdown]
# # compare btween all five stocks

# %%
plt.xlabel("Date")
plt.ylabel('Close')
plt.plot(df1.Date,df1.Close, label='Bosch')
plt.plot(df2.Date,df2.Close, label='Apple')
plt.plot(df3.Date,df3.Close, label='Intel')
plt.plot(df4.Date,df4.Close, label='IBM')
plt.plot(df5.Date,df5.Close, label='Microsoft')
plt.legend()

# %% [markdown]
# # Now Indexing

# %%
# df1['Date']=pd.to_datetime(df1.Date)

df1['Date']= pd.to_datetime(df1.Date, format='%Y-%m-%d')
# rcParams['figure.figsize']=16,7
# df1.index=df1['Date']
# plt.title('Bosch')

# # plt.xlabel('Date')
# # plt.ylabel("Close price")

# plt.plot(df1.Close );

df1.set_index('Date')['Close'].plot()

# %%
df1['Date'] = pd.to_datetime(df1.Date , format = '%Y-%m-%d')
df1.index = df1['Date']

plt.figure(figsize=(20,7))
plt.plot(df1['Close'], label = "Bosch")

# %%
df2['Date']=pd.to_datetime(df2.Date)

df2['Date']= pd.to_datetime(df2.Date, format='%d-%m-%Y')
rcParams['figure.figsize']=16,6
df2.index=df2['Date']
plt.title('APPLE')
plt.xlabel('Date')
plt.ylabel("Close price")

plt.plot(df2['Close'], label='Close price')
plt.legend()

# %%
df3['Date']=pd.to_datetime(df3.Date)

df3['Date']= pd.to_datetime(df3.Date, format='%D-%m-%y')
rcParams['figure.figsize']=16,6
df3.index=df3['Date']
plt.title('INTEL')
plt.xlabel('Date')
plt.ylabel("Close price")

plt.plot(df3['Close'], label='Close price')
plt.legend()

# %%
df4['Date']=pd.to_datetime(df4.Date)

df4['Date']= pd.to_datetime(df4.Date, format='%D-%m-%d')
rcParams['figure.figsize']=16,6
df4.index=df4['Date']
plt.title('IBM')
plt.xlabel('Date')
plt.ylabel("Close price")

plt.plot(df4['Close'], label='Close price')
plt.legend()

# %%
# df5['Date']=pd.to_datetime(df5.Date)

df5['Date']= pd.to_datetime(df5.Date, format='%Y-%m-%d')
# rcParams['figure.figsize']=16,6
df5.index=df5['Date']
# plt.title('MICROSOFT CORPORATION')
# plt.xlabel('Date')
# plt.ylabel("Close price")
plt.figure(figsize=(18,8))
plt.plot(df5['Close'], label='Close price')
# plt.legend()

# %% [markdown]
# # Feature Scaling use of MinMaxScaler vs StandardScaler

# %%
# first import 

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

df= pd.read_csv('/content/drive/MyDrive/data analatics/AAPL.csv')
print(df)
df.head()
# Out:
#       Unnamed: 0 symbol  ... divCash  splitFactor
# 0              0   AAPL  ...     0.0          1.0
# 1              1   AAPL  ...     0.0          1.0
# 2              2   AAPL  ...     0.0          1.0
# 3              3   AAPL  ...     0.0          1.0
# 4              4   AAPL  ...     0.0          1.0
# ...          ...    ...  ...     ...          ...
# 1253        1253   AAPL  ...     0.0          1.0
# 1254        1254   AAPL  ...     0.0          1.0
# 1255        1255   AAPL  ...     0.0          1.0
# 1256        1256   AAPL  ...     0.0          1.0
# 1257        1257   AAPL  ...     0.0          1.0
#
# [1258 rows x 15 columns]
#    Unnamed: 0 symbol  ... divCash  splitFactor
# 0           0   AAPL  ...     0.0          1.0
# 1           1   AAPL  ...     0.0          1.0
# 2           2   AAPL  ...     0.0          1.0
# 3           3   AAPL  ...     0.0          1.0
# 4           4   AAPL  ...     0.0          1.0
#
# [5 rows x 15 columns]

# %% [markdown]
# # StandardScaler

# %%
stnd=StandardScaler()
df_standerd_scaler=stnd.fit_transform(df[['open','close','low','high']])
df_standerd_scaler
# Out:
# array([[-0.65750369, -0.62783971, -0.64285248, -0.64321905],
#        [-0.63064392, -0.63250289, -0.62409729, -0.64861249],
#        [-0.64177658, -0.65889824, -0.64553179, -0.65731158],
#        ...,
#        [ 2.63529253,  2.66603573,  2.68217447,  2.6147645 ],
#        [ 2.67028092,  2.62415511,  2.67627998,  2.63860001],
#        [ 2.61921201,  2.66005279,  2.6669917 ,  2.60971903]])

# %% [markdown]
# # MinMaxScaler

# %%
# it is for Minimaxscaler

min=MinMaxScaler()
df_mini_scaler=min.fit_transform(df[['open','close','low','high']])
print(df_mini_scaler)
# Out:
# [[0.17185703 0.17607447 0.17350778 0.17186045]
#  [0.17833255 0.17495567 0.17799726 0.17054789]
#  [0.17564862 0.16862282 0.17286643 0.16843086]
#  ...
#  [0.96570528 0.96635143 0.96942877 0.96473029]
#  [0.9741405  0.9563033  0.96801779 0.97053095]
#  [0.96182848 0.96491598 0.96579442 0.96350241]]

# %% [markdown]
# # This for StandardScaler

# %%
# now plot the graph for 
plt.xlabel('Date')
plt.ylabel("all prices")
# df['Date']=pd.to_datetime(df.Date)

# df['Date']= pd.to_datetime(df.Date, format='%D-%m-%y')
# rcParams['figure.figsize']=16,6
# df.index=df['Date']
# df.set_index('Date')[df_standerd_scaler].plot()
plt.plot(df.date,df_standerd_scaler ,label="INTEL prices scaler")
plt.legend()

# %% [markdown]
# # This is for MinMaxScaler

# %%
plt.xlabel('Date')
plt.ylabel("all prices")

plt.plot(df.date,df_mini_scaler, label='label="INTEL prices scaler' )
plt.legend()

# %% [markdown]
# # Now I am going to Stock prediction using stacked LSTM

# %% [markdown]
# The Stacked LSTM is an extension to this model that has multiple hidden LSTM layers where each layer contains multiple memory cells.
#
#
# In stacked LSTMs, each LSTM layer outputs a sequence of vectors which will be used as an input to a subsequent LSTM layer.

# %% [markdown]
#   **scenario of this Task**
#
# 1. I have collect the stcok data - **APPLE.csv**
#
# 2.  I have to preprocess of the data as a **Train and Test**
#
# 3.  I have create a  stacked  **LSTM** **MODEL**
#
# 4. After this the predict Test data and Plot the Output
#
# 5. last is that i Have predict the fiture 30 day data and Plot Output

# %%
import numpy as np
import pandas as pd

# %%
Df=pd.read_csv('/content/drive/MyDrive/data analatics/AAPL.csv')
Df.head()
# Out:
#    Unnamed: 0 symbol  ... divCash  splitFactor
# 0           0   AAPL  ...     0.0          1.0
# 1           1   AAPL  ...     0.0          1.0
# 2           2   AAPL  ...     0.0          1.0
# 3           3   AAPL  ...     0.0          1.0
# 4           4   AAPL  ...     0.0          1.0
#
# [5 rows x 15 columns]

# %%
df7=Df.reset_index()['close']
df7.shape
df7.head()
# Out:
# 0    132.045
# 1    131.780
# 2    130.280
# 3    130.535
# 4    129.960
# Name: close, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,8))
plt.plot(df7)

# %% [markdown]
# # LSTM are senstitive to the scale of the data . so we apply Minmax scales
#
# #where we transform the value as a 0 to  1

# %%
print(df7)
# Out:
# 0       132.045
# 1       131.780
# 2       130.280
# 3       130.535
# 4       129.960
#          ...
# 1253    314.960
# 1254    313.140
# 1255    319.230
# 1256    316.850
# 1257    318.890
# Name: close, Length: 1258, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df7=scaler.fit_transform(np.array(df7).reshape(-1,1))
print(df7)
# Out:
# [[0.17607447]
#  [0.17495567]
#  [0.16862282]
#  ...
#  [0.96635143]
#  [0.9563033 ]
#  [0.96491598]]

# %% [markdown]
# # I have to preprocess of the data as a Train and Test

# %%
train_size=int(len(df7)*0.65)
test_size=len(df7)-train_size
train_data,test_data=df7[0:train_size],df7[train_size:len(df7)]

# %%
# traninig_size ,test_size

# %%
len(train_data) , len(test_data)
# Out:
# (817, 441)

# %% [markdown]
# # now I am going to procising of my data

# %%
# convert an array of values into a dataset matrix
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (716, 100)
# (716,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (340, 100)
# (340,)
# (None, None)

# %% [markdown]
# # reshape input to be [samples, time steps, features] which is required for LSTM

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
X_test.shape
# Out:
# (340, 100, 1)

# %%
X_train.shape
# Out:
# (716, 100, 1)

# %% [markdown]
# # Create the Stacked LSTM model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 8s 263ms/step - loss: 0.0199 - val_loss: 0.0696
# Epoch 2/100
# 12/12 [==============================] - 2s 163ms/step - loss: 0.0041 - val_loss: 0.0048
# Epoch 3/100
# 12/12 [==============================] - 2s 161ms/step - loss: 0.0012 - val_loss: 0.0040
# Epoch 4/100
# 12/12 [==============================] - 2s 166ms/step - loss: 8.6047e-04 - val_loss: 0.0045
# Epoch 5/100
# 12/12 [==============================] - 2s 165ms/step - loss: 7.3447e-04 - val_loss: 0.0085
# Epoch 6/100
# 12/12 [==============================] - 2s 167ms/step - loss: 7.0452e-04 - val_loss: 0.0075
# Epoch 7/100
# 12/12 [==============================] - 2s 172ms/step - loss: 6.7711e-04 - val_loss: 0.0059
# Epoch 8/100
# 12/12 [==============================] - 2s 168ms/step - loss: 6.4603e-04 - val_loss: 0.0049
# Epoch 9/100
# 12/12 [==============================] - 2s 167ms/step - loss: 6.2516e-04 - val_loss: 0.0051
# Epoch 10/100
# ...

# %%
y_prediction=model.predict(X_test)

# %%
# from sklearn.metrics import accuracy_score
# accuracy_score()

# %%
# import tenserflow

import tensorflow as tf

# %% [markdown]
# #Lets Do the prediction and check performance metrics

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
print(train_predict)
print(test_predict)
# Out:
# [[0.09290953]
#  [0.09304028]
#  [0.09300007]
#  [0.09382653]
#  [0.09555899]
#  [0.09853076]
#  [0.10378186]
#  [0.10888792]
#  [0.11216971]
#  [0.11528679]
#  [0.11913006]
#  [0.12294538]
#  [0.12681587]
#  [0.13096322]
#  [0.13465859]
#  [0.13684429]
#  [0.13738933]
#  [0.1364139 ]
#  [0.13271275]
#  [0.12677658]
#  [0.11989119]
#  [0.11197147]
#  [0.10494348]
#  [0.09968594]
#  [0.09808823]
#  [0.10059448]
#  [0.1062532 ]
#  [0.11266265]
#  [0.11866369]
#  [0.12298967]
#  [0.12512636]
#  [0.12550575]
#  [0.12428312]
#  [0.12159156]
#  [0.11766728]
#  [0.11505811]
#  [0.11417423]
#  [0.11472711]
#  [0.11497705]
#  [0.1146476 ]
#  [0.11253295]
#  [0.10867369]
#  [0.1031363 ]
#  [0.09737594]
#  [0.09152521]
#  [0.08499822]
#  [0.0789649 ]
#  [0.07422822]
#  [0.0717214 ]
#  [0.07117865]
#  [0.07156315]
#  [0.07302161]
#  [0.07465298]
#  [0.07513376]
#  [0.07430603]
#  [0.07150692]
#  [0.06651179]
#  [0.05866088]
#  [0.04942445]
#  [0.04109644]
#  [0.03546511]
#  [0.03197589]
# ...

# %%
train_predict.shape
# Out:
# (716, 1)

# %% [markdown]
# # Transformback to original form

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
import math
from sklearn.metrics import mean_squared_error

# %% [markdown]
# which is a metric that tells us the average distance between the predicted values from the model and the actual values in the dataset

# %% [markdown]
# # Mean square error of my y_train and train_predict

# %%
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 143.15018024132758

# %% [markdown]
# # Mean square error of my ytest and test_predict

# %%
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 241.86411858989808

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(df7)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df7)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df7)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df7))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
len(test_data)
# Out:
# 441

# %%
x_input=test_data[341:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
temp_input
# Out:
# [0.8583551465000423,
#  0.8866418981676942,
#  0.8743139407244789,
#  0.8843198513890065,
#  0.8783669678290975,
#  0.8986321033521913,
#  0.925821160179009,
#  0.9287764924427933,
#  0.9567677108840666,
#  0.9386979650426415,
#  0.933040614709111,
#  0.9495060373216249,
#  0.9642404796082076,
#  0.9551211686228154,
#  0.9598919192772104,
#  0.9663514312251966,
#  0.9624672802499368,
#  0.9229502659799038,
#  0.9598497002448705,
#  0.9879253567508233,
#  0.985941062230854,
#  0.9253145317909315,
#  0.9217259140420504,
#  0.964747107996285,
#  0.9757240564046274,
#  0.9915984125643842,
#  0.9697289538123788,
#  0.9761462467280253,
#  0.9679557544541082,
#  1.0000000000000002,
#  0.9901629654648318,
#  0.9905007177235499,
#  0.9653803934813816,
#  0.9848855864223593,
#  0.9708688676855528,
#  0.9402600692392133,
#  0.8774803681499621,
#  0.8348391454867856,
#  0.8541332432660644,
#  0.7733682344000676,
#  0.7726927298826314,
#  0.8801401671873683,
#  0.8400743054969182,
# ...

# %% [markdown]
# # demonstrate prediction for next 30 days with the respect of my model
#
# # That is feture prediction for next 30 days

# %%
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<30):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

print(lst_output)
# Out:
# [0.97834784]
# 101
# 1 day input [0.8866419  0.87431394 0.88431985 0.87836697 0.8986321  0.92582116
#  0.92877649 0.95676771 0.93869797 0.93304061 0.94950604 0.96424048
#  0.95512117 0.95989192 0.96635143 0.96246728 0.92295027 0.9598497
#  0.98792536 0.98594106 0.92531453 0.92172591 0.96474711 0.97572406
#  0.99159841 0.96972895 0.97614625 0.96795575 1.         0.99016297
#  0.99050072 0.96538039 0.98488559 0.97086887 0.94026007 0.87748037
#  0.83483915 0.85413324 0.77336823 0.77269273 0.88014017 0.84007431
#  0.89673225 0.85527316 0.83884995 0.74233725 0.82327113 0.78143207
#  0.6665963  0.7921557  0.64118044 0.68614371 0.66001013 0.65203074
#  0.58642236 0.56586169 0.66089673 0.65515494 0.70970193 0.66452757
#  0.69437642 0.69218104 0.63569197 0.65266402 0.63780292 0.7267162
#  0.71388162 0.74191506 0.75002111 0.77222832 0.83049059 0.8194292
#  0.8289707  0.8125475  0.78776492 0.75162543 0.78426074 0.77974331
#  0.81326522 0.8141096  0.79473106 0.83336148 0.85898843 0.83901883
# ...

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,131)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # this is my final 30 days feture prediction graph

# %%
plt.plot(day_new,scaler.inverse_transform(df7[1158:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))

# %%
df7=scaler.inverse_transform(df7).tolist()

plt.plot(df7)

# %% [markdown]
# # this a Liberay for analyze the data

# %%
data=pd.read_csv("/content/drive/MyDrive/data analatics/AAPL.csv")
data.head()
# Out:
#    Unnamed: 0 symbol  ... divCash  splitFactor
# 0           0   AAPL  ...     0.0          1.0
# 1           1   AAPL  ...     0.0          1.0
# 2           2   AAPL  ...     0.0          1.0
# 3           3   AAPL  ...     0.0          1.0
# 4           4   AAPL  ...     0.0          1.0
#
# [5 rows x 15 columns]

# %%
import pandas as np
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv('/content/drive/MyDrive/data analatics/AAPL.csv')
data
# Out:
#       Unnamed: 0 symbol  ... divCash  splitFactor
# 0              0   AAPL  ...     0.0          1.0
# 1              1   AAPL  ...     0.0          1.0
# 2              2   AAPL  ...     0.0          1.0
# 3              3   AAPL  ...     0.0          1.0
# 4              4   AAPL  ...     0.0          1.0
# ...          ...    ...  ...     ...          ...
# 1253        1253   AAPL  ...     0.0          1.0
# 1254        1254   AAPL  ...     0.0          1.0
# 1255        1255   AAPL  ...     0.0          1.0
# 1256        1256   AAPL  ...     0.0          1.0
# 1257        1257   AAPL  ...     0.0          1.0
#
# [1258 rows x 15 columns]

# %%
data=data[["close"]]
data.head
# Out:
# <bound method NDFrame.head of         close
# 0     132.045
# 1     131.780
# 2     130.280
# 3     130.535
# 4     129.960
# ...       ...
# 1253  314.960
# 1254  313.140
# 1255  319.230
# 1256  316.850
# 1257  318.890
#
# [1258 rows x 1 columns]>

# %%
futuare_days=25
data['predicction']=data[['close']].shift(-futuare_days)
data.tail()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        close  predicction
# 1253  314.96          NaN
# 1254  313.14          NaN
# 1255  319.23          NaN
# 1256  316.85          NaN
# 1257  318.89          NaN

# %%
x=np.array(data.drop(['predicction'],1))[:-futuare_days]
print(x)
# Out:
# [[132.045]
#  [131.78 ]
#  [130.28 ]
#  ...
#  [284.43 ]
#  [286.69 ]
#  [282.8  ]]

# %%
y=np.array(data['predicction'])[:-futuare_days]
print(y)
# Out:
# [126.6  126.44 126.   ... 319.23 316.85 318.89]

# %%
from sklearn.model_selection import  train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.65)

# %%
tree=DecisionTreeRegressor().fit(x_train,y_train)

# %%
lr=LinearRegression().fit(x_train,y_train)

# %%
tree_prediction=tree.predict(x_test)

# %%
tree_prediction
# Out:
# array([153.39 , 214.45 ,  96.45 , 110.06 , 183.92 , 116.28 , 220.65 ,
#        109.81 ,  98.53 , 273.36 , 298.39 , 172.29 , 226.41 , 113.09 ,
#        183.92 , 106.94 , 186.79 , 121.94 , 273.25 , 112.31 , 192.28 ,
#        170.41 , 105.26 , 184.92 , 308.66 , 144.02 , 159.88 , 210.35 ,
#        107.68 , 193.89 , 171.11 , 149.04 , 171.27 , 199.46 , 168.11 ,
#        271.46 , 178.97 , 216.3  , 209.68 , 146.28 , 101.12 , 178.44 ,
#        186.05 , 186.05 , 122.57 , 106.05 , 124.5  , 208.49 , 162.94 ,
#        116.17 , 212.24 , 143.65 , 208.88 , 213.28 , 167.37 , 209.68 ,
#        123.38 , 194.15 , 151.02 , 190.91 , 201.55 , 289.03 , 115.97 ,
#        171.11 ,  95.53 , 116.02 , 183.365, 141.63 , 201.55 , 168.11 ,
#        207.74 , 113.69 , 214.45 , 155.7  , 249.05 , 151.02 , 112.48 ,
#        170.95 , 192.23 , 174.35 , 159.76 , 201.55 , 174.38 , 144.77 ,
#        221.19 , 199.25 , 194.15 , 100.41 , 162.94 , 180.94 , 113.95 ,
# ...

# %%
lr_prediction=lr.predict(x_test)

# %%
lr_prediction
# Out:
# array([163.88991224, 225.18510916, 120.94140945, 121.2270761 ,
#        190.77212877, 123.39420238, 220.11698882, 100.74773268,
#        118.95159349, 319.5191314 , 269.27135325, 218.36358664,
#        209.55717346, 112.35170889, 190.77212877, 102.98381299,
#        173.68138283, 120.29127156, 290.43038627, 121.96586915,
#        187.77755427, 144.94725837, 122.4386967 , 189.44230128,
#        293.71062743, 143.18400562, 158.41299307, 208.0598862 ,
#        100.85608899, 200.34688674, 178.68547444, 157.80225748,
#        167.19970511, 193.49088721, 156.40347597, 259.0858597 ,
#        181.20722139, 219.8608739 , 201.04627749, 155.44797029,
#         98.58060639, 165.71226843, 171.25814161, 171.29754391,
#        112.79498472,  97.45764095, 131.62928228, 232.08543627,
#        178.31115262, 125.5514781 , 222.78649438, 144.37592508,
#        188.37843928, 214.89618458, 177.07983087, 201.41074873,
#        131.126903  , 205.26232318, 149.82329252, 194.18042739,
# ...

# %%
from sklearn import model_selection

print("for decisiontree :", mean_squared_error(tree_prediction,y_test))

print("for linearregression:", mean_squared_error(lr_prediction,y_test))
# Out:
# for decisiontree : 385.22028273067326
# for linearregression: 296.26495772749706

# %% [markdown]
# # Compare Accureccy of Three Algorithm
#
# 1.LSTM.
#
# 2.DecisionTreeRegressor.
#
# 3.LinearRegression.

# %% [markdown]
# #1.Stacked LSTM Root Mean Square Error

# %%
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 241.86411858989808

# %% [markdown]
# #2.DecisionTreeRegressor. Root Mean Square Error

# %%
math.sqrt(mean_squared_error(tree_prediction,y_test))
# Out:
# 19.627029391394746

# %% [markdown]
# #3.LinearRegression.Root Mean Square Error

# %%
math.sqrt(mean_squared_error(lr_prediction,y_test))
# Out:
# 17.212348989243075
